# %% [markdown]
# **using this there is no need to reload your packages every time when you will make any improvement to them**

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
autoreload 2

# %% [markdown]
# **import necessary libraries**

# %%
import numpy as np
import pandas as pd 
import sys
import warnings

# %%
from matplotlib import pyplot as plt

# %%
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN

# %% [markdown]
# **import modelling helpers**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **set pandas options**

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 200

# %% [markdown]
# **set warnings options**

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# #### to have ease in importing modules

# %%
sys.path.insert(0, '/Users/mjasiecz/PycharmProjects/new_offer_success_predictor/src')

# %% [markdown]
# **load data**

# %%
from data.data_manager import DataManager
from ml_preprocessing.categorical_encoders import LeaveOneOutEncoder

# %%
DM = DataManager()

# %%
df = DM.load_data()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1289 entries, C7CBB5C5613449B to B8A3C4B5FDE74D2
# Data columns (total 14 columns):
# offer_class           1289 non-null object
# accepted              1289 non-null object
# gender                1289 non-null object
# age                   877 non-null float64
# phone_calls           1286 non-null float64
# emails                1287 non-null float64
# customer_code         1265 non-null object
# salary                1281 non-null float64
# offer_code            1287 non-null object
# customer_type         1287 non-null object
# number                1280 non-null object
# offer_value           1277 non-null float64
# estimated_expenses    1286 non-null float64
# center                1286 non-null object
# dtypes: float64(6), object(8)
# memory usage: 151.1+ KB

# %%
DM.create_train_test()
# Out:
# Split is already done. Do not data snoop!

# %%
train_df, test_df = DM.load_train_test()

# %%
test_df.drop(columns=['accepted'], inplace=True)

# %% [markdown]
# #### dealing with missing values

# %% [markdown]
# how much missing values?

# %%
df.isnull().sum()
# Out:
# offer_class             0
# accepted                0
# gender                  0
# age                   412
# phone_calls             3
# emails                  2
# customer_code          24
# salary                  8
# offer_code              2
# customer_type           2
# number                  9
# offer_value            12
# estimated_expenses      3
# center                  3
# dtype: int64

# %% [markdown]
# percentage of missing values

# %%
print((df.isnull().sum()/df.shape[0]*100).round(2))
# Out:
# offer_class            0.00
# accepted               0.00
# gender                 0.00
# age                   31.96
# phone_calls            0.23
# emails                 0.16
# customer_code          1.86
# salary                 0.62
# offer_code             0.16
# customer_type          0.16
# number                 0.70
# offer_value            0.93
# estimated_expenses     0.23
# center                 0.23
# dtype: float64

# %% [markdown]
# # prepare something similar to automatize it on test set

# %% [markdown]
# #### emails and phone_calls columns - dealing with these columns / (without dividing process onto parts - missing, outliers etc)

# %% [markdown]
# #### emails

# %%
train_df['emails'].mean()
# Out:
# 0.9271137026239067

# %%
round(train_df['emails'].mean())
# Out:
# 1.0

# %%
train_df['cat_emails'] = train_df['emails']

# %%
train_df.loc[train_df['cat_emails'].isna(), 'cat_emails'] = round(train_df['emails'].mean())

# %%
train_df[train_df['emails']>4]['accepted'].value_counts()
# Out:
# no     11
# yes     1
# Name: accepted, dtype: int64

# %%
train_df.loc[train_df['cat_emails'] > 4, 'cat_emails'] = 5

# %%
train_df['cat_emails'] = train_df['cat_emails'].astype(object)

# %% [markdown]
# #### phone_calls

# %%
train_df['phone_calls'].mean()
# Out:
# 0.5150631681243926

# %%
round(train_df['phone_calls'].mean())
# Out:
# 1.0

# %%
train_df['cat_phone_calls'] = train_df['phone_calls']

# %%
train_df.loc[train_df['cat_phone_calls'].isna(), 'cat_phone_calls'] = round(train_df['phone_calls'].mean())

# %%
train_df[train_df['phone_calls']>3]['accepted'].value_counts()
# Out:
# no     30
# yes     2
# Name: accepted, dtype: int64

# %%
train_df.loc[train_df['cat_phone_calls'] > 3, 'cat_phone_calls'] = 4

# %%
train_df['cat_phone_calls'] = train_df['cat_phone_calls'].astype(object)

# %% [markdown]
# #### check after every iteration :)

# %%
train_df.isnull().sum()
# Out:
# accepted                0
# offer_class             0
# gender                  0
# age                   343
# phone_calls             2
# emails                  2
# customer_code          16
# salary                  7
# offer_code              2
# customer_type           2
# number                  6
# offer_value            10
# estimated_expenses      3
# center                  2
# cat_emails              0
# cat_phone_calls         0
# dtype: int64

# %%
cc = train_df[train_df['salary'].isnull()]['customer_code'].tolist()

# %%
# here i need to show that every person with the same salary has the same customer_code

# %%
train_df[train_df['customer_code'].isin(cc)]
# Out:
#                 accepted offer_class  gender   age  phone_calls  emails  \
# name
# 29C5493CE7EF447      yes      Medium  female  22.0          1.0     1.0
# BFAEC8F911F841B       no     Premium    male  32.0          1.0     0.0
# CA249ABE7D4E43C      yes      Medium  female   NaN          1.0     0.0
# 2D7B8459CBD2414      yes      Medium    male  50.0          2.0     0.0
# A14D00E1FEBF433       no     Premium    male  60.5          0.0     0.0
# FFFDD0C3B34644E       no      Medium    male  42.0          1.0     1.0
# 487662632F6B484      yes      Medium  female  35.0          1.0     0.0
# EF319AAD8691472       no      Medium    male  29.0          1.0     1.0
# CCF5A463D3BC472      yes     Premium  female   NaN          0.0     0.0
# 63193E3CA0F840B      yes     Premium  female  33.0          3.0     0.0
# DAF778DD00F8407      yes      Medium    male  32.0          0.0     1.0
#
#                 customer_code   salary offer_code customer_type number  \
# name
# 29C5493CE7EF447        113776   6660.0        D78             S  7D77D
# BFAEC8F911F841B       3101278      NaN        9C0             S  52591
# CA249ABE7D4E43C      PC 17611  13365.0        57E             S  E4391
# 2D7B8459CBD2414      PC 17611      NaN        2F3             S  8997E
# A14D00E1FEBF433          3701      NaN        05A             S  00D61
# FFFDD0C3B34644E        113789   5200.0        CE9             S  4272B
# 487662632F6B484        113789      NaN        B04             S  4DBC4
# EF319AAD8691472        113776      NaN        88A             S  7DFE9
# CCF5A463D3BC472         14313      NaN        6F2             Q  D21EF
# 63193E3CA0F840B       3101278   1585.0        46D             S  A3D8B
# DAF778DD00F8407         13214      NaN        F22             C  55CC4
#
#                  offer_value  estimated_expenses center cat_emails  \
# name
# 29C5493CE7EF447    61.329828              2754.0      A          1
# BFAEC8F911F841B   137.395918              5384.0      B          0
# CA249ABE7D4E43C   101.924325              1534.0      B          0
# 2D7B8459CBD2414    90.384374              5152.0      B          0
# A14D00E1FEBF433    80.832678              7521.0      A          0
# FFFDD0C3B34644E    66.355074              5090.0      A          1
# 487662632F6B484    60.800476              7570.0      A          0
# EF319AAD8691472    85.213460              4003.0      A          1
# CCF5A463D3BC472   260.922393              2631.0      A          0
# 63193E3CA0F840B    76.753846              2650.0      B          0
# DAF778DD00F8407    54.717256              6754.0      A          1
#
#                 cat_phone_calls
# name
# 29C5493CE7EF447               1
# BFAEC8F911F841B               1
# CA249ABE7D4E43C               1
# 2D7B8459CBD2414               2
# A14D00E1FEBF433               0
# FFFDD0C3B34644E               1
# 487662632F6B484               1
# EF319AAD8691472               1
# CCF5A463D3BC472               0
# 63193E3CA0F840B               3
# DAF778DD00F8407               0

# %%
train_df[train_df['salary'] == 0]
# Out:
#                 accepted offer_class gender   age  phone_calls  emails  \
# name
# C9DE5A2E7BC24AB       no      Medium   male  40.0          0.0     1.0
# 8816EB571C6B435       no        High   male   NaN          0.0     0.0
# B9A7CAE408AC42E       no        High   male   NaN          0.0     1.0
# 3515F26EEEFA40C       no      Medium   male   NaN          0.0     0.0
# 59273C9523B94F0       no     Premium   male  19.0          0.0     0.0
# 4669F129273C41C       no        High   male   NaN          0.0     0.0
# 27AE9D32887D47D       no        High   male   NaN          0.0     0.0
# 36EF30F44B644F4       no     Premium   male  49.0          0.0     1.0
# 27C908A4720E4AD       no      Medium   male  39.0          0.0     0.0
# 3FA638BEB4CD498       no      Medium   male   NaN          0.0     0.0
# 101708E21256413       no     Premium   male  36.0          0.0     1.0
#
#                 customer_code  salary offer_code customer_type number  \
# name
# C9DE5A2E7BC24AB        112059     0.0   0.00E+00             S  29B9B
# 8816EB571C6B435        239853     0.0        302             S  A5285
# B9A7CAE408AC42E        239855     0.0        F82             S  C1685
# 3515F26EEEFA40C           NaN     0.0        D04             S  91D26
# 59273C9523B94F0          LINE     0.0        EB6             S  FA978
# 4669F129273C41C        239853     0.0        B02             S  58287
# 27AE9D32887D47D        239853     0.0        DAC             S  4CA98
# 36EF30F44B644F4          LINE     0.0        624             S  688F8
# 27C908A4720E4AD        112050     0.0        9A1             S  90915
# 3FA638BEB4CD498        112052     0.0   6.00E+09             S  26A16
# 101708E21256413          LINE     0.0        BA8             S  AC698
#
#                  offer_value  estimated_expenses center cat_emails  \
# name
# C9DE5A2E7BC24AB   176.279975              5579.0      A          1
# 8816EB571C6B435   146.192831              2825.0      A          0
# B9A7CAE408AC42E    77.400738              3649.0      B          1
# 3515F26EEEFA40C   111.165165              2077.0      B          0
# 59273C9523B94F0   178.460182              7885.0      A          0
# 4669F129273C41C   119.168887              7642.0      B          0
# 27AE9D32887D47D   159.785647              6931.0      A          0
# 36EF30F44B644F4   150.333741              3976.0      A          1
# 27C908A4720E4AD   289.613239              2146.0      A          0
# 3FA638BEB4CD498    86.234876              3164.0      B          0
# 101708E21256413    54.693602              4933.0      B          1
#
#                 cat_phone_calls
# name
# C9DE5A2E7BC24AB               0
# 8816EB571C6B435               0
# B9A7CAE408AC42E               0
# 3515F26EEEFA40C               0
# 59273C9523B94F0               0
# 4669F129273C41C               0
# 27AE9D32887D47D               0
# 36EF30F44B644F4               0
# 27C908A4720E4AD               0
# 3FA638BEB4CD498               0
# 101708E21256413               0

# %%
cc1 = train_df[train_df['salary'] == 0]['customer_code'].tolist()

# %%
train_df[train_df['customer_code'].isin(cc1)]
# Out:
#                 accepted offer_class  gender   age  phone_calls  emails  \
# name
# 4CF2BD7C25314F0       no     Premium    male  38.5          0.0     1.0
# C9DE5A2E7BC24AB       no      Medium    male  40.0          0.0     1.0
# 8816EB571C6B435       no        High    male   NaN          0.0     0.0
# B9A7CAE408AC42E       no        High    male   NaN          0.0     1.0
# 6DF656E9901B476       no     Premium    male  21.0          0.0     0.0
# 3515F26EEEFA40C       no      Medium    male   NaN          0.0     0.0
# E915D2F2863B474       no     Premium    male  20.0          0.0     1.0
# 074B66A3B9F2426      yes        High  female  45.0          0.0     1.0
# 59273C9523B94F0       no     Premium    male  19.0          0.0     0.0
# 4669F129273C41C       no        High    male   NaN          0.0     0.0
# 8E6B0807AD104D7       no     Premium    male  23.0          0.0     0.0
# C4A9677BA45B43C       no     Premium    male  35.0          0.0     0.0
# 27AE9D32887D47D       no        High    male   NaN          0.0     0.0
# CF4FAA2E68594EC       no        High    male  18.0          0.0     0.0
# C0A1632D225F4A2       no     Premium    male  19.0          0.0     0.0
# B0879F9FBD22410      yes     Premium    male  32.0          0.0     0.0
# D88499042B154AA      yes        High  female   NaN          2.0     1.0
# 36EF30F44B644F4       no     Premium    male  49.0          0.0     1.0
# EF8FE41F792541E       no     Premium  female   NaN          1.0     2.0
# 3E8BC12335394B7       no      Medium    male  31.0          0.0     0.0
# 27C908A4720E4AD       no      Medium    male  39.0          0.0     0.0
# 3FA638BEB4CD498       no      Medium    male   NaN          0.0     0.0
# AE5A310EA521402      yes     Premium    male  20.0          1.0     1.0
# F88C8FB8BD4D40F       no     Premium    male  32.0          0.0     1.0
# 101708E21256413       no     Premium    male  36.0          0.0     1.0
# 81B0FCC40A1A452      yes     Premium  female   NaN          0.0     0.0
#
#                 customer_code   salary offer_code customer_type number  \
# name
# 4CF2BD7C25314F0           NaN   725.00   1.00E+00             S  120AA
# C9DE5A2E7BC24AB        112059     0.00   0.00E+00             S  29B9B
# 8816EB571C6B435        239853     0.00        302             S  A5285
# B9A7CAE408AC42E        239855     0.00        F82             S  C1685
# 6DF656E9901B476           NaN   725.00        BE2             S  69D51
# 3515F26EEEFA40C           NaN     0.00        D04             S  91D26
# E915D2F2863B474           NaN   705.00         85             S  A167C
# 074B66A3B9F2426           NaN  1350.00   8.00E+06             S  DF9E0
# 59273C9523B94F0          LINE     0.00        EB6             S  FA978
# 4669F129273C41C        239853     0.00        B02             S  58287
# 8E6B0807AD104D7           NaN   705.00        AE3             S  C0B81
# C4A9677BA45B43C           NaN   705.00        EC8             S  0DA74
# 27AE9D32887D47D        239853     0.00        DAC             S  4CA98
# CF4FAA2E68594EC           NaN  1050.00        CD9             S  67407
# C0A1632D225F4A2           NaN   765.00        8B8             S  53DF3
# B0879F9FBD22410           NaN   805.00        708             S  8BFF2
# D88499042B154AA           NaN  3900.00        C9B             S  974ED
# 36EF30F44B644F4          LINE     0.00        624             S  688F8
# EF8FE41F792541E           NaN  1218.33        51A             S  01ED4
# 3E8BC12335394B7           NaN  5049.58        C46             S  CABDB
# 27C908A4720E4AD        112050     0.00        9A1             S  90915
# 3FA638BEB4CD498        112052     0.00   6.00E+09             S  26A16
# AE5A310EA521402           NaN   792.50        854             S  0A6F0
# F88C8FB8BD4D40F           NaN   792.50         74             S  931C9
# 101708E21256413          LINE     0.00        BA8             S  AC698
# 81B0FCC40A1A452           NaN   775.00   5.00E+08             Q  CA06D
#
#                  offer_value  estimated_expenses center cat_emails  \
# name
# 4CF2BD7C25314F0    98.242553              5182.0      A          1
# C9DE5A2E7BC24AB   176.279975              5579.0      A          1
# 8816EB571C6B435   146.192831              2825.0      A          0
# B9A7CAE408AC42E    77.400738              3649.0      B          1
# 6DF656E9901B476   199.381070              2755.0      B          0
# 3515F26EEEFA40C   111.165165              2077.0      B          0
# E915D2F2863B474   102.076908              3416.0      B          1
# 074B66A3B9F2426   155.645549              3849.0      B          1
# 59273C9523B94F0   178.460182              7885.0      A          0
# 4669F129273C41C   119.168887              7642.0      B          0
# 8E6B0807AD104D7    94.696626              6896.0      B          0
# C4A9677BA45B43C   101.855806              7326.0      B          0
# 27AE9D32887D47D   159.785647              6931.0      A          0
# CF4FAA2E68594EC    71.000387              2940.0      A          0
# C0A1632D225F4A2   196.190720              3232.0      B          0
# B0879F9FBD22410    50.523511              5366.0      B          0
# D88499042B154AA    65.646576              1962.0      A          1
# 36EF30F44B644F4   150.333741              3976.0      A          1
# EF8FE41F792541E   126.415769              4767.0      B          2
# 3E8BC12335394B7    94.017023              6535.0      B          0
# 27C908A4720E4AD   289.613239              2146.0      A          0
# 3FA638BEB4CD498    86.234876              3164.0      B          0
# AE5A310EA521402   198.719171              5943.0      A          1
# F88C8FB8BD4D40F    86.357199              5545.0      A          1
# 101708E21256413    54.693602              4933.0      B          1
# 81B0FCC40A1A452    95.234189              5130.0      B          0
#
#                 cat_phone_calls
# name
# 4CF2BD7C25314F0               0
# C9DE5A2E7BC24AB               0
# 8816EB571C6B435               0
# B9A7CAE408AC42E               0
# 6DF656E9901B476               0
# 3515F26EEEFA40C               0
# E915D2F2863B474               0
# 074B66A3B9F2426               0
# 59273C9523B94F0               0
# 4669F129273C41C               0
# 8E6B0807AD104D7               0
# C4A9677BA45B43C               0
# 27AE9D32887D47D               0
# CF4FAA2E68594EC               0
# C0A1632D225F4A2               0
# B0879F9FBD22410               0
# D88499042B154AA               2
# 36EF30F44B644F4               0
# EF8FE41F792541E               1
# 3E8BC12335394B7               0
# 27C908A4720E4AD               0
# 3FA638BEB4CD498               0
# AE5A310EA521402               1
# F88C8FB8BD4D40F               0
# 101708E21256413               0
# 81B0FCC40A1A452               0

# %%
test_df.isnull().sum()
# Out:
# offer_class            0
# gender                 0
# age                   69
# phone_calls            1
# emails                 0
# customer_code          8
# salary                 1
# offer_code             0
# customer_type          0
# number                 3
# offer_value            2
# estimated_expenses     0
# center                 1
# dtype: int64

# %%
train_df['salary_modif'] = train_df['salary']
train_df.loc[train_df['salary_modif'].isna(), 'salary_modif'] = 0.1

# %%
ccctsalary = train_df[['customer_type', 'customer_code', 'salary_modif']].groupby(['customer_code' , 'customer_type', 'salary_modif']).size().reset_index().rename(columns={0:'size'})# .duplicated(subset=['customer_code', 'customer_type'])

# %%
ccctsalary.shape
# Out:
# (757, 4)

# %%
#ccctsalary

# %%
slownik = ccctsalary[ccctsalary.duplicated(subset=['customer_code', 'customer_type'], keep=False)][['customer_code', 'salary_modif']]

# %%
slownik = slownik[slownik['salary_modif'] != 0.1]

# %%
slownik = slownik.set_index('customer_code')['salary_modif']

# %%
slownik = slownik.to_dict()

# %%
slownik
# Out:
# {'113776': 6660.0,
#  '113789': 5200.0,
#  '3101278': 1585.0,
#  '7534': 984.58,
#  'PC 17611': 13365.0}

# %%
train_df['salary'].isna().sum()
# Out:
# 7

# %%
train_df['salary'].fillna(train_df['customer_code'].map(slownik)).isna().sum()
# Out:
# 3

# %%
train_df[train_df['salary'].isna()].groupby('customer_type').size()
# Out:
# customer_type
# C    1
# Q    1
# S    5
# dtype: int64

# %%
#train_df[['customer_code', 'salary']].sort_values('salary')

# %%
#train_df['customer_code'].fillna('cc_missing')

# %%
#train_df['number'].fillna('number_missing')

# %%
#train_df['']

# %%
train_df.head()
# Out:
#                 accepted offer_class  gender   age  phone_calls  emails  \
# name
# 8550AB469CB2445       no     Premium  female   NaN          1.0     2.0
# 07355EE27DD1493       no        High    male  32.0          0.0     0.0
# 034E73A251554F0      yes     Premium  female   NaN          1.0     1.0
# 0AF961B4AC7A439       no     Premium    male   NaN          0.0     1.0
# 8535BBCA690A4AE      yes     Premium    male   NaN          0.0     1.0
#
#                 customer_code   salary offer_code customer_type number  \
# name
# 8550AB469CB2445          2678  1524.58        8CA             C  0F2A2
# 07355EE27DD1493        244360  1300.00        9DD             S  5F15A
# 034E73A251554F0        370365  1550.00        517             Q  AC578
# 0AF961B4AC7A439          2652   722.92        9CB             C  8A8CC
# 8535BBCA690A4AE          1601  5649.58        6FF             S  42EFB
#
#                  offer_value  estimated_expenses center cat_emails  \
# name
# 8550AB469CB2445   303.973257              7207.0      B          2
# 07355EE27DD1493    64.075055              3675.0      A          0
# 034E73A251554F0   108.581750              4750.0      B          1
# 0AF961B4AC7A439   155.495957              1401.0      A          1
# 8535BBCA690A4AE   121.371033              2106.0      B          1
#
#                 cat_phone_calls  salary_modif
# name
# 8550AB469CB2445               1       1524.58
# 07355EE27DD1493               0       1300.00
# 034E73A251554F0               1       1550.00
# 0AF961B4AC7A439               0        722.92
# 8535BBCA690A4AE               0       5649.58

# %%
train_df[['customer_type', 'offer_value']].groupby('customer_type').mean().reset_index()
# Out:
#   customer_type  offer_value
# 0             C   129.787996
# 1             Q   117.489225
# 2             S   129.230987

# %%
train_df['cc_startswith_a'] = train_df['customer_code'].str.startswith('A')
train_df['cc_startswith_p'] = train_df['customer_code'].str.startswith('P')
train_df['cc_startswith_c'] = train_df['customer_code'].str.startswith('C')
train_df['cc_len_5'] = train_df['customer_code'].str.len() == 5

# %%
import pandas as pd
import numpy as np
import itertools

from collections import defaultdict
from fancyimpute import KNN

from sklearn.preprocessing import StandardScaler

class DataProcessor:
    """

    """
    def __init__(self, train_df: pd.DataFrame) -> None:
        self.df = train_df.copy(deep=True)
    
    def missing_information(self, percentage: bool = False) -> pd.Series:
        df_shape = self.df.shape
        print(f'df.shape: {df_shape}')
        is_null_sum = self.df.isnull().sum()
        missing_information = is_null_sum if not percentage else (is_null_sum/df_shape[0]*100).round(2)
        return missing_information
    
    @staticmethod
    def _group_columns():
        groups = defaultdict()
        groups['age'] = ['age']
        groups['emails_and_phone_calls'] = ['emails', 'phone_calls']
        groups['low_cardinality'] = ['offer_class', 'gender', 'customer_type', 'center']
        groups['high_cardinality'] = ['customer_code', 'offer_code', 'number']
        groups['numerical'] = ['salary', 'offer_value', 'estimated_expenses']
        groups['target'] = ['accepted']
        return groups
    
    @staticmethod
    def _missing_salary(df: pd.Series):
        df = df.copy(deep=True)
        df['salary_temp'] = df['salary'].fillna(0.1)
        mask = ['customer_type', 'customer_code', 'salary_temp']
        temp = df[mask].groupby(mask).size().reset_index().rename(columns={0: 'size'})
        temp = temp[temp.duplicated(subset=['customer_code', 'customer_type'], keep=False)][['customer_code', 'salary_temp']]
        temp = temp[temp['salary_temp'] != 0.1]
        temp = temp.set_index('customer_code')['salary_temp']
        salary_map = temp.to_dict()
        df['salary'] = df['salary'].fillna(df['customer_code'].map(salary_map))
        temp = df[['customer_type', 'salary']].groupby('customer_type').median()
        temp = temp['salary']
        salary_map = temp.to_dict()
        df['salary'] = df['salary'].fillna(df['customer_type'].map(salary_map))
        # to be able to np.log('salary')
        df.loc[df['salary'] == 0, 'salary'] = 0.0001
        return df['salary']

    def _prepare_to_knn(self, df: pd.DataFrame):
        df = df.copy(deep=True)
        temp = pd.get_dummies(df['gender'])
        groups = self._group_columns()
        if 'accepted' in df.columns:
            temp = pd.concat([pd.get_dummies(df['accepted']), temp], axis=1)
        for col in itertools.chain(groups['emails_and_phone_calls'], groups['low_cardinality']):
            temp = pd.concat([pd.get_dummies(df[col]), temp], axis=1)
        knn_to_complete = pd.concat([temp, df[groups['numerical']+groups['age']]], axis=1)
        return knn_to_complete
                                 
    def deal_with_missing_values(self, n_neighbors: int = 5):
        df = self.df.copy(deep=True)
        groups = self._group_columns()
        for col in groups['high_cardinality']:
            df[col] = df[col].fillna('missing')
        
        def _prt_process_emails_and_phone_calls(df):
            df.loc[df['emails'] > 4, 'emails'] = 5
            df.loc[df['phone_calls'] > 3, 'phone_calls'] = 4
            return df
        
        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].fillna(round(df[col].mean()))
        
        df = _prt_process_emails_and_phone_calls(df)
            
        for col in groups['low_cardinality']:
            df[col] = df[col].fillna(method='ffill')
        df['salary'] = self._missing_salary(df)
        temp = df[groups['emails_and_phone_calls']+groups['age']+groups['low_cardinality']+groups['numerical']]
        knn_unfilled_table = self._prepare_to_knn(temp)
        knn_filled = KNN(k=n_neighbors, print_interval=1032).fit_transform(knn_unfilled_table.to_numpy())
        knn_imputed_cols = ['age_knn', 'estimated_expenses_knn', 'offer_value_knn']
        for col in knn_imputed_cols:
            df[col] = knn_filled[:,-knn_imputed_cols.index(col)-1]
        df = df.drop(columns=['offer_value', 'estimated_expenses'])
        return df
    
    @staticmethod
    def _process_age(age_df: pd.DataFrame) -> pd.DataFrame:
        age_df = age_df.copy(deep=True)
        age_df['nan_age'] = age_df['age'].isna()
        age_df['not_nan_age'] = age_df['age'].notna()
        return age_df[['nan_age', 'not_nan_age']]
        
    @staticmethod
    def _process_target(target_df: pd.DataFrame) -> pd.DataFrame:
        target = target_df['accepted'] == 'yes'
        return target

    
    @staticmethod
    def _process_high_cardinality_categorical_cols(high_cardinality_df: pd.DataFrame) -> pd.DataFrame:
        pass
    
    @staticmethod
    def _process_numerical_cols(numerical_df: pd.DataFrame) -> pd.DataFrame:
        numeric_cols = [col for col in numerical_df.columns if numerical_df[col].dtype != object]
        numeric_cols.remove('age')
        temp = numerical_df[numeric_cols]
        scaler = StandardScaler()
        for col in numeric_cols:
            temp['log_'+col] = np.log(temp[col])
        log_cols = [col for col in temp.columns if col not in numerical_df.columns]
        log_subset = temp[log_cols]
        temp_subset = temp[numeric_cols]
        scaled = scaler.fit_transform(temp_subset)
        scaled = pd.DataFrame(scaled, columns='scaled_'+temp_subset.columns, index=temp.index)
        processed = pd.concat([log_subset, scaled], axis=1)
        return processed
        
        
        
        
    def perform_initial_features_engineering(self):
        groups = self._group_columns()
        df = self.deal_with_missing_values().copy(deep=True)
        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].astype(object)        
        target = self._process_target(df)
        age = self._process_age(df)
        numerical = self._process_numerical_cols(df)
        df = pd.concat([target, df], axis=1)
        df = pd.concat([age, df], axis=1)
        df = pd.concat([numerical, df], axis=1)
        return df

# %%
import itertools
from collections import defaultdict

import numpy as np
import pandas as pd
from fancyimpute import KNN
from sklearn.preprocessing import StandardScaler


class DataProcessor:
    """
    """

    def __init__(self, train_df: pd.DataFrame) -> None:
        """

        :param train_df:
        """
        self.df = train_df.copy(deep=True)

    def missing_information(self, percentage: bool = False) -> pd.Series:
        """

        :param percentage:
        :return:
        """
        df_shape = self.df.shape
        print(f'df.shape: {df_shape}')
        is_null_sum = self.df.isnull().sum()
        missing_information = (is_null_sum
                               if not percentage
                               else (is_null_sum / df_shape[0] * 100).round(2))
        return missing_information

    @staticmethod
    def _group_columns():
        """

        :return:
        """
        groups = defaultdict()
        groups['age'] = ['age']
        groups['emails_and_phone_calls'] = ['emails', 'phone_calls']
        groups['low_cardinality'] = ['offer_class', 'gender', 'customer_type', 'center']
        groups['high_cardinality'] = ['customer_code', 'offer_code', 'number']
        groups['numerical'] = ['salary', 'offer_value', 'estimated_expenses']
        groups['target'] = ['accepted']
        return groups

    @staticmethod
    def _missing_salary(df: pd.DataFrame):
        """

        :param df:
        :return:
        """
        df = df.copy(deep=True)
        df['salary_temp'] = df['salary'].fillna(0.1)
        mask = ['customer_type', 'customer_code', 'salary_temp']
        temp = (df[mask]
                .groupby(mask)
                .size()
                .reset_index()
                .rename(columns={0: 'size'}))
        temp = (temp[temp
            .duplicated(subset=['customer_code', 'customer_type'],
                        keep=False)][['customer_code', 'salary_temp']])
        temp = temp[temp['salary_temp'] != 0.1]
        temp = temp.set_index('customer_code')['salary_temp']
        salary_map = temp.to_dict()
        df['salary'] = (df['salary']
                        .fillna(df['customer_code']
                                .map(salary_map)))
        temp = (df[['customer_type', 'salary']]
                .groupby('customer_type')
                .median())
        temp = temp['salary']
        salary_map = temp.to_dict()
        df['salary'] = (df['salary']
                        .fillna(df['customer_type']
                                .map(salary_map)))
        # to be able to np.log('salary')
        df.loc[df['salary'] == 0, 'salary'] = 0.0001
        return df['salary']

    def _prepare_to_knn(self, df: pd.DataFrame):
        """

        :param df:
        :return:
        """
        df = df.copy(deep=True)
        temp = pd.get_dummies(df['gender'])
        groups = self._group_columns()
        if 'accepted' in df.columns:
            temp = pd.concat([pd.get_dummies(df['accepted']), temp], axis=1)
        for col in itertools.chain(groups['emails_and_phone_calls'], groups['low_cardinality']):
            temp = pd.concat([pd.get_dummies(df[col]), temp], axis=1)
        knn_to_complete = pd.concat([temp, df[groups['numerical'] + groups['age']]], axis=1)
        return knn_to_complete

    def deal_with_missing_values(self, n_neighbors: int = 5):
        """

        :param n_neighbors:
        :return:
        """
        df = self.df.copy(deep=True)
        groups = self._group_columns()
        for col in groups['high_cardinality']:
            df[col] = df[col].fillna('missing')

        def _prt_process_emails_and_phone_calls(emails_phone_calls_df: pd.DataFrame):
            """

            :param emails_phone_calls_df:
            :return:
            """
            emails_phone_calls_df.loc[emails_phone_calls_df['emails'] > 4, 'emails'] = 5
            emails_phone_calls_df.loc[emails_phone_calls_df['phone_calls'] > 3, 'phone_calls'] = 4
            return emails_phone_calls_df

        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].fillna(round(df[col].mean()))

        df = _prt_process_emails_and_phone_calls(df)

        for col in groups['low_cardinality']:
            df[col] = df[col].fillna(method='ffill')
        df['salary'] = self._missing_salary(df)
        temp = (df[groups['emails_and_phone_calls']
                   + groups['age']
                   + groups['low_cardinality']
                   + groups['numerical']])
        knn_unfilled_table = self._prepare_to_knn(temp)
        knn_filled = (KNN(k=n_neighbors,
                         print_interval=1032)
                      .fit_transform(knn_unfilled_table
                                     .to_numpy()))
        knn_imputed_cols = ['age_knn', 'estimated_expenses_knn', 'offer_value_knn']
        for col in knn_imputed_cols:
            df[col] = knn_filled[:, -knn_imputed_cols.index(col) - 1]
        df = df.drop(columns=['offer_value', 'estimated_expenses'])
        return df

    @staticmethod
    def _process_age(age_df: pd.DataFrame) -> pd.DataFrame:
        """

        :param age_df:
        :return:
        """
        age_df = age_df.copy(deep=True)
        age_df['nan_age'] = age_df['age'].isna()
        age_df['not_nan_age'] = age_df['age'].notna()
        return age_df[['nan_age', 'not_nan_age']]

    @staticmethod
    def _process_target(target_df: pd.DataFrame) -> pd.DataFrame:
        """

        :param target_df:
        :return:
        """
        target_df = target_df.copy(deep=True)
        target_df['target'] = target_df['accepted'] == 'yes'
        return target_df[['target']]

    @staticmethod
    def _process_high_cardinality_categorical_cols(high_cardinal_df: pd.DataFrame) -> pd.DataFrame:
        """

        :param high_cardinal_df:
        :return:
        """
        high_cardinal_df = high_cardinal_df.copy(deep=True)
        high_cardinal_df['cc_len'] = high_cardinal_df['customer_code'].str.len()
        high_cardinal_df.loc[high_cardinal_df['cc_len'].isin([5,8]), 'cc_len'] = '58'
        high_cardinal_df.loc[~high_cardinal_df['cc_len'].isin(['58']), 'cc_len'] = 'ELSE'
        high_cardinal_df['cc_startswith'] = high_cardinal_df['customer_code']
        a_p_c = ['A', 'P', 'C']
        for letter in a_p_c:
            high_cardinal_df.loc[high_cardinal_df['customer_code'].str.startswith(letter), 'cc_startswith'] = letter
        high_cardinal_df.loc[~high_cardinal_df['customer_code'].str.startswith(tuple(a_p_c)), 'cc_startswith'] = 'ELSE'
        return high_cardinal_df[['cc_len', 'cc_startswith']]
        

    @staticmethod
    def _process_numerical_cols(numerical_df: pd.DataFrame) -> pd.DataFrame:
        """

        :param numerical_df:
        :return:
        """
        numeric_cols = [col for col in numerical_df.columns if numerical_df[col].dtype != object]
        numeric_cols.remove('age')
        temp = numerical_df[numeric_cols]
        scaler = StandardScaler()
        for col in numeric_cols:
            temp['log_' + col] = np.log(temp[col])
        log_cols = [col for col in temp.columns if col not in numerical_df.columns]
        log_subset = temp[log_cols]
        temp_subset = temp[numeric_cols]
        scaled = scaler.fit_transform(temp_subset)
        scaled = pd.DataFrame(scaled, columns='scaled_' + temp_subset.columns, index=temp.index)
        processed = pd.concat([log_subset, scaled], axis=1)
        return processed

    def perform_initial_features_engineering(self):
        """

        :return:
        """
        groups = self._group_columns()
        df = self.deal_with_missing_values().copy(deep=True)
        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].astype(object)
        target = self._process_target(df)
        age = self._process_age(df)
        numerical = self._process_numerical_cols(df)
        high_cardinal = self._process_high_cardinality_categorical_cols(df)
        df = pd.concat([target, df], axis=1)
        df = pd.concat([age, df], axis=1)
        df = pd.concat([numerical, df], axis=1)
        df = pd.concat([high_cardinal, df], axis=1)
        df.drop(columns=['accepted', 'customer_code', 'number', 'offer_code'], inplace=True)
        
        if False:
            df.to_csv('/data/processed/processed_train.csv')
            
        
        return df

class TestDataProcessor(DataProcessor):
    
class TrainDataProcessor(DataProcessor):
# Out:
#   File "<ipython-input-579-55fbe9ef5186>", line 235
#     class TrainDataProcessor(DataProcessor):
#         ^
# IndentationError: expected an indented block

# %%
DP = DataProcessor(train_df)

# %%
a = DP.perform_initial_features_engineering()
# Out:
# Imputing row 1/1031 with 1 missing, elapsed time: 0.230

# %%
a.shape
# Out:
# (1031, 24)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1031 entries, 8550AB469CB2445 to 358EEC4160A4478
# Data columns (total 24 columns):
# cc_len                           1031 non-null object
# cc_startswith                    1031 non-null object
# log_salary                       1031 non-null float64
# log_age_knn                      1031 non-null float64
# log_estimated_expenses_knn       1031 non-null float64
# log_offer_value_knn              1031 non-null float64
# scaled_salary                    1031 non-null float64
# scaled_age_knn                   1031 non-null float64
# scaled_estimated_expenses_knn    1031 non-null float64
# scaled_offer_value_knn           1031 non-null float64
# nan_age                          1031 non-null bool
# not_nan_age                      1031 non-null bool
# target                           1031 non-null bool
# offer_class                      1031 non-null object
# gender                           1031 non-null object
# age                              688 non-null float64
# phone_calls                      1031 non-null object
# emails                           1031 non-null object
# salary                           1031 non-null float64
# customer_type                    1031 non-null object
# center                           1031 non-null object
# age_knn                          1031 non-null float64
# estimated_expenses_knn           1031 non-null float64
# offer_value_knn                  1031 non-null float64
# dtypes: bool(3), float64(13), object(8)
# memory usage: 180.2+ KB

# %%
train_df[train_df['salary'].isna()]
# Out:
#                 accepted offer_class  gender   age  phone_calls  emails  \
# name
# BFAEC8F911F841B       no     Premium    male  32.0          1.0     0.0
# 2D7B8459CBD2414      yes      Medium    male  50.0          2.0     0.0
# A14D00E1FEBF433       no     Premium    male  60.5          0.0     0.0
# 487662632F6B484      yes      Medium  female  35.0          1.0     0.0
# EF319AAD8691472       no      Medium    male  29.0          1.0     1.0
# CCF5A463D3BC472      yes     Premium  female   NaN          0.0     0.0
# DAF778DD00F8407      yes      Medium    male  32.0          0.0     1.0
#
#                 customer_code  salary offer_code customer_type number  \
# name
# BFAEC8F911F841B       3101278     NaN        9C0             S  52591
# 2D7B8459CBD2414      PC 17611     NaN        2F3             S  8997E
# A14D00E1FEBF433          3701     NaN        05A             S  00D61
# 487662632F6B484        113789     NaN        B04             S  4DBC4
# EF319AAD8691472        113776     NaN        88A             S  7DFE9
# CCF5A463D3BC472         14313     NaN        6F2             Q  D21EF
# DAF778DD00F8407         13214     NaN        F22             C  55CC4
#
#                  offer_value  estimated_expenses center
# name
# BFAEC8F911F841B   137.395918              5384.0      B
# 2D7B8459CBD2414    90.384374              5152.0      B
# A14D00E1FEBF433    80.832678              7521.0      A
# 487662632F6B484    60.800476              7570.0      A
# EF319AAD8691472    85.213460              4003.0      A
# CCF5A463D3BC472   260.922393              2631.0      A
# DAF778DD00F8407    54.717256              6754.0      A

# %%
a.head()
# Out:
#                 cc_len cc_startswith  log_salary  log_age_knn  \
# name
# 8550AB469CB2445   ELSE          ELSE    7.329474     3.401259
# 07355EE27DD1493   ELSE          ELSE    7.170120     3.465736
# 034E73A251554F0   ELSE          ELSE    7.346010     3.177471
# 0AF961B4AC7A439   ELSE          ELSE    6.583299     3.323884
# 8535BBCA690A4AE   ELSE          ELSE    8.639336     3.405772
#
#                  log_estimated_expenses_knn  log_offer_value_knn  \
# name
# 8550AB469CB2445                    8.882808             5.716940
# 07355EE27DD1493                    8.209308             4.160055
# 034E73A251554F0                    8.465900             4.687503
# 0AF961B4AC7A439                    7.244942             5.046620
# 8535BBCA690A4AE                    7.652546             4.798852
#
#                  scaled_salary  scaled_age_knn  scaled_estimated_expenses_knn  \
# name
# 8550AB469CB2445      -0.345530       -0.297159                       1.362250
# 07355EE27DD1493      -0.389281       -0.111655                      -0.492006
# 034E73A251554F0      -0.340578       -0.855654                       0.072355
# 0AF961B4AC7A439      -0.501704       -0.504546                      -1.685828
# 8535BBCA690A4AE       0.458072       -0.284561                      -1.315712
#
#                  scaled_offer_value_knn  nan_age  not_nan_age  target  \
# name
# 8550AB469CB2445                3.035567     True        False   False
# 07355EE27DD1493               -1.109564    False         True   False
# 034E73A251554F0               -0.340546     True        False    True
# 0AF961B4AC7A439                0.470071     True        False   False
# 8535BBCA690A4AE               -0.119564     True        False    True
#
#                 offer_class  gender   age phone_calls emails   salary  \
# name
# 8550AB469CB2445     Premium  female   NaN           1      2  1524.58
# 07355EE27DD1493        High    male  32.0           0      0  1300.00
# 034E73A251554F0     Premium  female   NaN           1      1  1550.00
# 0AF961B4AC7A439     Premium    male   NaN           0      1   722.92
# 8535BBCA690A4AE     Premium    male   NaN           0      1  5649.58
#
#                 customer_type center    age_knn  estimated_expenses_knn  \
# name
# 8550AB469CB2445             C      B  30.001848                  7207.0
# 07355EE27DD1493             S      A  32.000000                  3675.0
# 034E73A251554F0             Q      B  23.986022                  4750.0
# 0AF961B4AC7A439             C      A  27.767979                  1401.0
# 8535BBCA690A4AE             S      B  30.137541                  2106.0
#
#                  offer_value_knn
# name
# 8550AB469CB2445       303.973257
# 07355EE27DD1493        64.075055
# 034E73A251554F0       108.581750
# 0AF961B4AC7A439       155.495957
# 8535BBCA690A4AE       121.371033

# %%
train_df[train_df['customer_code'] == 'PC 17611']
# Out:
#                 accepted offer_class  gender   age  phone_calls  emails  \
# name
# CA249ABE7D4E43C      yes      Medium  female   NaN          1.0     0.0
# 2D7B8459CBD2414      yes      Medium    male  50.0          2.0     0.0
#
#                 customer_code   salary offer_code customer_type number  \
# name
# CA249ABE7D4E43C      PC 17611  13365.0        57E             S  E4391
# 2D7B8459CBD2414      PC 17611      NaN        2F3             S  8997E
#
#                  offer_value  estimated_expenses center
# name
# CA249ABE7D4E43C   101.924325              1534.0      B
# 2D7B8459CBD2414    90.384374              5152.0      B

# %%
a[a.index == '2D7B8459CBD2414']['salary']
# Out:
# name
# 2D7B8459CBD2414    13365.0
# Name: salary, dtype: float64

# %%
import itertools
from collections import defaultdict

import numpy as np
import pandas as pd
from fancyimpute import KNN
from sklearn.preprocessing import StandardScaler


class DataProcessor:
    """
    processes data, is well adapted for processing training DataFrame,
    - deals with missing data,
    - converts column types for further work (CategoricalEncoding of categorical columns),
    - performs initial features engineering
    """

    def __init__(self, train_df: pd.DataFrame) -> None:
        """
        :param train_df: training DataFrame
        """
        self.df = train_df.copy(deep=True)

    def missing_information(self, percentage: bool = False) -> pd.Series:
        """
        shows us information about missing data

        :param percentage: set to True, if you want to have percentage information on the output
        :return: Series with information on missing rows in each column
        """
        df_shape = self.df.shape
        print(f'df.shape: {df_shape}')
        is_null_sum = self.df.isnull().sum()
        missing_information = (is_null_sum
                               if not percentage
                               else (is_null_sum / df_shape[0] * 100).round(2))
        return missing_information

    @staticmethod
    def _group_columns() -> defaultdict:
        """
        returns dictionary with logically grouped columns
        """
        groups = defaultdict()
        groups['age'] = ['age']
        groups['emails_and_phone_calls'] = ['emails', 'phone_calls']
        groups['low_cardinality'] = ['offer_class', 'gender', 'customer_type', 'center']
        groups['high_cardinality'] = ['customer_code', 'offer_code', 'number']
        groups['numerical'] = ['salary', 'offer_value', 'estimated_expenses']
        groups['target'] = ['accepted']
        return groups

    @staticmethod
    def _missing_salary(df: pd.DataFrame) -> pd.Series:
        """
        fills missing data in salary column:
        for people with the same customer_code fills the same data as in other row,
        for other people
        """
        df = df.copy(deep=True)
        df['salary_temp'] = df['salary'].fillna(0.1)
        mask = ['customer_type', 'customer_code', 'salary_temp']
        temp = (df[mask]
                .groupby(mask)
                .size()
                .reset_index()
                .rename(columns={0: 'size'}))
        temp = (temp[temp
                .duplicated(subset=['customer_code', 'customer_type'],
                            keep=False)][['customer_code', 'salary_temp']])
        temp = temp[temp['salary_temp'] != 0.1]
        temp = temp.set_index('customer_code')['salary_temp']
        salary_map = temp.to_dict()
        df['salary'] = (df['salary']
                        .fillna(df['customer_code']
                                .map(salary_map)))
        temp = (df[['customer_type', 'salary']]
                .groupby('customer_type')
                .median())
        temp = temp['salary']
        salary_map = temp.to_dict()
        df['salary'] = (df['salary']
                        .fillna(df['customer_type']
                                .map(salary_map)))
        # to be able to np.log('salary')
        df.loc[df['salary'] == 0, 'salary'] = 0.0001
        return df['salary']

    def _prepare_to_knn(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        prepares data for knn imputing (of missing data)
        for training data uses also labels to give more information then to test set
        """
        df = df.copy(deep=True)
        temp = pd.get_dummies(df['gender'])
        groups = self._group_columns()
        if 'accepted' in df.columns:
            temp = pd.concat([pd.get_dummies(df['accepted']), temp], axis=1)
        for col in itertools.chain(groups['emails_and_phone_calls'], groups['low_cardinality']):
            temp = pd.concat([pd.get_dummies(df[col]), temp], axis=1)
        knn_to_complete = pd.concat([temp, df[groups['numerical'] + groups['age']]], axis=1)
        return knn_to_complete

    def deal_with_missing_values(self, n_neighbors: int = 5) -> pd.DataFrame:
        """
        :param n_neighbors: number of neighbours for knn algorithm
        :return: returns DataFrame with filled nans (also, leaves unchanged 'age' column ->
        to be used further for possible age binning)
        """
        df = self.df.copy(deep=True)
        groups = self._group_columns()
        for col in groups['high_cardinality']:
            df[col] = df[col].fillna('missing')

        def _prt_process_emails_and_phone_calls(
                emails_phone_calls_df: pd.DataFrame) -> pd.DataFrame:
            """
            initially processes emails and phone_calls columns:
            models some outliers with almost full no responses, to have constant value
            """
            emails_phone_calls_df.loc[emails_phone_calls_df['emails'] > 4, 'emails'] = 5
            emails_phone_calls_df.loc[emails_phone_calls_df['phone_calls'] > 3, 'phone_calls'] = 4
            return emails_phone_calls_df

        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].fillna(round(df[col].mean()))

        df = _prt_process_emails_and_phone_calls(df)

        for col in groups['low_cardinality']:
            df[col] = df[col].fillna(method='ffill')
        df['salary'] = self._missing_salary(df)
        temp = (df[groups['emails_and_phone_calls']
                   + groups['age']
                   + groups['low_cardinality']
                   + groups['numerical']])
        knn_unfilled_table = self._prepare_to_knn(temp)
        knn_filled = (KNN(k=n_neighbors,
                          print_interval=1032)
                      .fit_transform(knn_unfilled_table
                                     .to_numpy()))
        knn_imputed_cols = ['age_knn', 'estimated_expenses_knn', 'offer_value_knn']
        for col in knn_imputed_cols:
            df[col] = knn_filled[:, -knn_imputed_cols.index(col) - 1]
        df = df.drop(columns=['offer_value', 'estimated_expenses'])
        return df

    @staticmethod
    def _process_age(age_df: pd.DataFrame) -> pd.DataFrame:
        """
        Divides age for 2 bins: where age is nan and opposite case
        (we consider situation, when it's possible that client does not gave us their age because
        he wasn't truly interested in cooperation with us)
        """
        age_df = age_df.copy(deep=True)
        age_df['nan_age'] = age_df['age'].isna()
        age_df['not_nan_age'] = age_df['age'].notna()
        return age_df[['nan_age', 'not_nan_age']]

    @staticmethod
    def _process_target(target_df: pd.DataFrame) -> pd.DataFrame:
        """
        Maps target:
        1 for accepted
        0 for not accepted
        (for ML algorithms purposes)
        """
        target_df = target_df.copy(deep=True)
        target_df['target'] = target_df['accepted'] == 'yes'
        return target_df[['target']]

    @staticmethod
    def _process_high_cardinality_categorical_cols(high_cardinal_df: pd.DataFrame) -> pd.DataFrame:
        """
        creates features for high cardinality categorical columns: (those which won't bring any
        additional value where encoded)
        at this moment we consider only customer_code column as profitable
        """
        high_cardinal_df = high_cardinal_df.copy(deep=True)
        high_cardinal_df['cc_len'] = high_cardinal_df['customer_code'].str.len()
        high_cardinal_df.loc[high_cardinal_df['cc_len'].isin([5, 8]), 'cc_len'] = '58'
        high_cardinal_df.loc[~high_cardinal_df['cc_len'].isin(['58']), 'cc_len'] = 'ELSE'
        high_cardinal_df['cc_startswith'] = high_cardinal_df['customer_code']
        a_p_c = ['A', 'P', 'C']
        for letter in a_p_c:
            (high_cardinal_df
                .loc[high_cardinal_df['customer_code']
                                      .str
                                      .startswith(letter), 'cc_startswith']) = letter
        (high_cardinal_df
            .loc[~high_cardinal_df['customer_code']
                                   .str
                                   .startswith(tuple(a_p_c)), 'cc_startswith']) = 'ELSE'
        return high_cardinal_df[['cc_len', 'cc_startswith']]

    @staticmethod
    def _process_numerical_cols(numerical_df: pd.DataFrame) -> pd.DataFrame:
        """
        creates features:
        - standard scales numerical columns,
        - log scales numerical columns,
        to consider three cases when modelling:
        only standard scaled, only log scaled, and mixed using variances
        """
        numeric_cols = [col for col in numerical_df.columns if numerical_df[col].dtype != object]
        numeric_cols.remove('age')
        temp = numerical_df[numeric_cols]
        scaler = StandardScaler()
        for col in numeric_cols:
            temp['log_' + col] = np.log(temp[col])
        log_cols = [col for col in temp.columns if col not in numerical_df.columns]
        log_subset = temp[log_cols]
        temp_subset = temp[numeric_cols]
        scaled = scaler.fit_transform(temp_subset)
        scaled = pd.DataFrame(scaled,
                              columns='scaled_' + temp_subset.columns,
                              index=temp.index)
        processed = pd.concat([log_subset, scaled], axis=1)
        return processed

    def perform_initial_features_engineering(self):
        """
        performs initial feature engineering (without encoding -> will be done as individual part
        due to some maintenance issues (how to cross validate target encoding?)
        """
        groups = self._group_columns()
        df = self.deal_with_missing_values().copy(deep=True)
        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].astype(object)
        age = self._process_age(df)
        numerical = self._process_numerical_cols(df)
        high_cardinal = self._process_high_cardinality_categorical_cols(df)
        columns_to_drop = ['customer_code', 'number', 'offer_code']
        if 'accepted' in df.columns:
            columns_to_drop.append('accepted')
            target = self._process_target(df)
            df = pd.concat([target, df], axis=1)
        df = pd.concat([age, df], axis=1)
        df = pd.concat([numerical, df], axis=1)
        df = pd.concat([high_cardinal, df], axis=1)
        df.drop(columns=columns_to_drop, inplace=True)

        return df


class TestDataProcessor(DataProcessor):
    """
    DataProcessor adapted to test set needs
    """

    def __init__(self, not_processed_train_df, processed_train_df, test_df, sneaky_peaky=True):
        """
        :param not_processed_train_df: self explanatory
        :param processed_train_df: self explanatory
        :param test_df: self explanatory
        :param sneaky_peaky: set to True:
            uses some knn columns as 'original' to bring a little 'overfitting' to test set.
            As we have only lot of missing values in age, tries to sneak some correlation between
            age and responses
        """
        DataProcessor.__init__(self, not_processed_train_df)

        if sneaky_peaky:
            self.df['age'] = processed_train_df['age_knn']
            self.df['estimated_expenses'] = processed_train_df['estimated_expenses_knn']
            self.df['offer_value'] = processed_train_df['offer_value_knn']
        self.df = (pd
                   .concat([self
                           .df
                           .drop(columns=['salary', 'accepted']), processed_train_df['salary']],
                           axis=1))

        self.train_len = len(processed_train_df)
        self.df = pd.concat([self.df, test_df], axis=0).copy(deep=True)

    def perform_initial_features_engineering(self):
        """
        performs initial features engineering on test set
        """
        df = DataProcessor.perform_initial_features_engineering(self)
        df = df[self.train_len:]

        return df

# %%
a.columns
# Out:
# Index(['cc_len', 'cc_startswith', 'log_salary', 'log_age_knn',
#        'log_estimated_expenses_knn', 'log_offer_value_knn', 'scaled_salary',
#        'scaled_age_knn', 'scaled_estimated_expenses_knn',
#        'scaled_offer_value_knn', 'nan_age', 'not_nan_age', 'target',
#        'offer_class', 'gender', 'age', 'phone_calls', 'emails', 'salary',
#        'customer_type', 'center', 'age_knn', 'estimated_expenses_knn',
#        'offer_value_knn'],
#       dtype='object')

# %%
#a

# %%
test_df['age'].isna().sum()
# Out:
# 69

# %%
test_df.shape
# Out:
# (258, 13)

# %%
import itertools
from collections import defaultdict

import numpy as np
import pandas as pd
from fancyimpute import KNN
from sklearn.preprocessing import StandardScaler


class DataProcessor:
    """
    processes data, is well adapted for processing training DataFrame,
    - deals with missing data,
    - converts column types for further work (CategoricalEncoding of categorical columns),
    - performs initial features engineering
    """

    def __init__(self, train_df: pd.DataFrame) -> None:
        """
        :param train_df: training DataFrame
        """
        self.df = train_df.copy(deep=True)

    def missing_information(self, percentage: bool = False) -> pd.Series:
        """
        shows us information about missing data

        :param percentage: set to True, if you want to have percentage information on the output
        :return: Series with information on missing rows in each column
        """
        df_shape = self.df.shape
        print(f'df.shape: {df_shape}')
        is_null_sum = self.df.isnull().sum()
        missing_information = (is_null_sum
                               if not percentage
                               else (is_null_sum / df_shape[0] * 100).round(2))
        return missing_information

    @staticmethod
    def _group_columns() -> defaultdict:
        """
        returns dictionary with logically grouped columns
        """
        groups = defaultdict()
        groups['age'] = ['age']
        groups['emails_and_phone_calls'] = ['emails', 'phone_calls']
        groups['low_cardinality'] = ['offer_class', 'gender', 'customer_type', 'center']
        groups['high_cardinality'] = ['customer_code', 'offer_code', 'number']
        groups['numerical'] = ['salary', 'offer_value', 'estimated_expenses']
        groups['target'] = ['accepted']
        return groups

    @staticmethod
    def _missing_salary(df: pd.DataFrame) -> pd.Series:
        """
        fills missing data in salary column:
        for people with the same customer_code fills the same data as in other row,
        for other people
        """
        df = df.copy(deep=True)
        df['salary_temp'] = df['salary'].fillna(0.1)
        mask = ['customer_type', 'customer_code', 'salary_temp']
        temp = (df[mask]
                .groupby(mask)
                .size()
                .reset_index()
                .rename(columns={0: 'size'}))
        temp = (temp[temp
                .duplicated(subset=['customer_code', 'customer_type'],
                            keep=False)][['customer_code', 'salary_temp']])
        temp = temp[temp['salary_temp'] != 0.1]
        temp = temp.set_index('customer_code')['salary_temp']
        salary_map = temp.to_dict()
        df['salary'] = (df['salary']
                        .fillna(df['customer_code']
                                .map(salary_map)))
        temp = (df[['customer_type', 'salary']]
                .groupby('customer_type')
                .median())
        temp = temp['salary']
        salary_map = temp.to_dict()
        df['salary'] = (df['salary']
                        .fillna(df['customer_type']
                                .map(salary_map)))
        # to be able to np.log('salary')
        df.loc[df['salary'] == 0, 'salary'] = 0.0001
        return df['salary']

    def _prepare_to_knn(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        prepares data for knn imputing (of missing data)
        for training data uses also labels to give more information then to test set
        """
        df = df.copy(deep=True)
        temp = pd.get_dummies(df['gender'])
        groups = self._group_columns()
        if 'accepted' in df.columns:
            temp = pd.concat([pd.get_dummies(df['accepted']), temp], axis=1)
        for col in itertools.chain(groups['emails_and_phone_calls'], groups['low_cardinality']):
            temp = pd.concat([pd.get_dummies(df[col]), temp], axis=1)
        knn_to_complete = pd.concat([temp, df[groups['numerical'] + groups['age']]], axis=1)
        return knn_to_complete

    def deal_with_missing_values(self, n_neighbors: int = 5) -> pd.DataFrame:
        """
        :param n_neighbors: number of neighbours for knn algorithm
        :return: returns DataFrame with filled nans (also, leaves unchanged 'age' column ->
        to be used further for possible age binning)
        """
        df = self.df.copy(deep=True)
        groups = self._group_columns()
        for col in groups['high_cardinality']:
            df[col] = df[col].fillna('missing')

        def _prt_process_emails_and_phone_calls(
                emails_phone_calls_df: pd.DataFrame) -> pd.DataFrame:
            """
            initially processes emails and phone_calls columns:
            models some outliers with almost full no responses, to have constant value
            """
            emails_phone_calls_df.loc[emails_phone_calls_df['emails'] > 4, 'emails'] = 5
            emails_phone_calls_df.loc[emails_phone_calls_df['phone_calls'] > 3, 'phone_calls'] = 4
            return emails_phone_calls_df

        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].fillna(round(df[col].mean()))

        df = _prt_process_emails_and_phone_calls(df)

        for col in groups['low_cardinality']:
            df[col] = df[col].fillna(method='ffill')
        df['salary'] = self._missing_salary(df)
        temp = (df[groups['emails_and_phone_calls']
                   + groups['age']
                   + groups['low_cardinality']
                   + groups['numerical']])
        knn_unfilled_table = self._prepare_to_knn(temp)
        knn_filled = (KNN(k=n_neighbors,
                          print_interval=1032)
                      .fit_transform(knn_unfilled_table
                                     .to_numpy()))
        knn_imputed_cols = ['age_knn', 'estimated_expenses_knn', 'offer_value_knn']
        for col in knn_imputed_cols:
            df[col] = knn_filled[:, -knn_imputed_cols.index(col) - 1]
        df = df.drop(columns=['offer_value', 'estimated_expenses'])
        return df

    @staticmethod
    def _process_age(age_df: pd.DataFrame) -> pd.DataFrame:
        """
        Divides age for 2 bins: where age is nan and opposite case
        (we consider situation, when it's possible that client does not gave us their age because
        he wasn't truly interested in cooperation with us)
        """
        age_df = age_df.copy(deep=True)
        age_df['nan_age'] = age_df['age'].isna()
        age_df['not_nan_age'] = age_df['age'].notna()
        return age_df[['nan_age', 'not_nan_age']]

    @staticmethod
    def _process_target(target_df: pd.DataFrame) -> pd.DataFrame:
        """
        Maps target:
        1 for accepted
        0 for not accepted
        (for ML algorithms purposes)
        """
        target_df = target_df.copy(deep=True)
        target_df['target'] = target_df['accepted'] == 'yes'
        return target_df[['target']]

    @staticmethod
    def _process_high_cardinality_categorical_cols(high_cardinal_df: pd.DataFrame) -> pd.DataFrame:
        """
        creates features for high cardinality categorical columns: (those which won't bring any
        additional value where encoded)
        at this moment we consider only customer_code column as profitable
        """
        high_cardinal_df = high_cardinal_df.copy(deep=True)
        high_cardinal_df['cc_len'] = high_cardinal_df['customer_code'].str.len()
        high_cardinal_df.loc[high_cardinal_df['cc_len'].isin([5, 8]), 'cc_len'] = '58'
        high_cardinal_df.loc[~high_cardinal_df['cc_len'].isin(['58']), 'cc_len'] = 'ELSE'
        high_cardinal_df['cc_startswith'] = high_cardinal_df['customer_code']
        a_p_c = ['A', 'P', 'C']
        for letter in a_p_c:
            (high_cardinal_df
                .loc[high_cardinal_df['customer_code']
                                      .str
                                      .startswith(letter), 'cc_startswith']) = letter
        (high_cardinal_df
            .loc[~high_cardinal_df['customer_code']
                                   .str
                                   .startswith(tuple(a_p_c)), 'cc_startswith']) = 'ELSE'
        return high_cardinal_df[['cc_len', 'cc_startswith']]

    @staticmethod
    def _process_numerical_cols(numerical_df: pd.DataFrame) -> pd.DataFrame:
        """
        creates features:
        - standard scales numerical columns,
        - log scales numerical columns,
        to consider three cases when modelling:
        only standard scaled, only log scaled, and mixed using variances
        """
        numeric_cols = [col for col in numerical_df.columns if numerical_df[col].dtype != object]
        numeric_cols.remove('age')
        temp = numerical_df[numeric_cols]
        scaler = StandardScaler()
        for col in numeric_cols:
            temp['log_' + col] = np.log(temp[col])
        log_cols = [col for col in temp.columns if col not in numerical_df.columns]
        log_subset = temp[log_cols]
        temp_subset = temp[numeric_cols]
        scaled = scaler.fit_transform(temp_subset)
        scaled = pd.DataFrame(scaled,
                              columns='scaled_' + temp_subset.columns,
                              index=temp.index)
        processed = pd.concat([log_subset, scaled], axis=1)
        return processed

    def perform_initial_features_engineering(self):
        """
        performs initial feature engineering (without encoding -> will be done as individual part
        due to some maintenance issues (how to cross validate target encoding?)
        """
        groups = self._group_columns()
        df = self.deal_with_missing_values().copy(deep=True)
        for col in groups['emails_and_phone_calls']:
            df[col] = df[col].astype(object)
        age = self._process_age(df)
        numerical = self._process_numerical_cols(df)
        high_cardinal = self._process_high_cardinality_categorical_cols(df)
        columns_to_drop = ['customer_code', 'number', 'offer_code']
        if 'accepted' in df.columns:
            columns_to_drop.append('accepted')
            target = self._process_target(df)
            df = pd.concat([target, df], axis=1)
        df = pd.concat([age, df], axis=1)
        df = pd.concat([numerical, df], axis=1)
        df = pd.concat([high_cardinal, df], axis=1)
        df.drop(columns=columns_to_drop, inplace=True)

        return df


class TestDataProcessor(DataProcessor):
    """
    DataProcessor adapted to test set needs
    """

    def __init__(self, not_processed_train_df, processed_train_df, test_df, sneaky_peaky=True):
        """
        :param not_processed_train_df: self explanatory
        :param processed_train_df: self explanatory
        :param test_df: self explanatory
        :param sneaky_peaky: set to True:
            uses some knn columns as 'original' to bring a little 'overfitting' to test set.
            As we have only lot of missing values in age, tries to sneak some correlation between
            age and responses
        """
        DataProcessor.__init__(self, not_processed_train_df)

        if sneaky_peaky:
            self.df['age'] = processed_train_df['age_knn']
            self.df['estimated_expenses'] = processed_train_df['estimated_expenses_knn']
            self.df['offer_value'] = processed_train_df['offer_value_knn']
        self.df = (pd
                   .concat([self
                           .df
                           .drop(columns=['salary', 'accepted']), processed_train_df['salary']],
                           axis=1))

        self.train_len = len(processed_train_df)
        self.df = pd.concat([self.df, test_df], axis=0).copy(deep=True)

    def perform_initial_features_engineering(self):
        """
        performs initial features engineering on test set
        """
        df = DataProcessor.perform_initial_features_engineering(self)
        df = df[self.train_len:]

        return df

# %%
TDP = TestDataProcessor(train_df, a, test_df, sneaky_peaky=True)

# %%
b = TDP.perform_initial_features_engineering()
# Out:
# Imputing row 1/1289 with 0 missing, elapsed time: 0.343
# Imputing row 1033/1289 with 0 missing, elapsed time: 0.345

# %%
c = TDP.perform_initial_features_engineering()
# Out:
# Imputing row 1/1289 with 1 missing, elapsed time: 0.366
# Imputing row 1033/1289 with 0 missing, elapsed time: 0.377

# %%
np.sum(c['age_knn'] != b['age_knn'])
# Out:
# 59

# %%
b.head()
# Out:
#                 cc_len cc_startswith  log_salary  log_age_knn  \
# name
# DA3BAEB8BF604EB   ELSE          ELSE    6.594755     3.489576
# AEF3DE08DFED4E0   ELSE          ELSE    6.656084     3.433987
# B621BB29484E46D   ELSE          ELSE    6.671501     3.218876
# 2D0945802F92423   ELSE          ELSE    6.514713     2.890372
# 640ABFC7E49B403     58          ELSE    8.029296     4.025352
#
#                  log_estimated_expenses_knn  log_offer_value_knn  \
# name
# DA3BAEB8BF604EB                    8.940891             4.963600
# AEF3DE08DFED4E0                    8.662851             4.153202
# B621BB29484E46D                    8.434898             5.348081
# 2D0945802F92423                    8.402680             4.876044
# 640ABFC7E49B403                    8.388450             5.193064
#
#                  scaled_salary  scaled_age_knn  scaled_estimated_expenses_knn  \
# name
# DA3BAEB8BF604EB      -0.501839       -0.035049                       1.603528
# AEF3DE08DFED4E0      -0.492946       -0.197055                       0.631794
# B621BB29484E46D      -0.490623       -0.745594                       0.013846
# 2D0945802F92423      -0.512654       -1.385557                      -0.062677
# 640ABFC7E49B403      -0.052226        2.088525                      -0.095697
#
#                  scaled_offer_value_knn  nan_age  not_nan_age   age center  \
# name
# DA3BAEB8BF604EB                0.246935     True        False   NaN      A
# AEF3DE08DFED4E0               -1.130746    False         True  31.0      A
# B621BB29484E46D                1.410101    False         True  25.0      B
# 2D0945802F92423                0.038956    False         True  18.0      B
# 640ABFC7E49B403                0.886816    False         True  56.0      B
#
#                 customer_type emails  gender offer_class phone_calls   salary  \
# name
# DA3BAEB8BF604EB             S      1    male     Premium           0   731.25
# AEF3DE08DFED4E0             S      0    male     Premium           0   777.50
# B621BB29484E46D             S      1    male     Premium           0   789.58
# 2D0945802F92423             Q      1  female     Premium           0   675.00
# 640ABFC7E49B403             C      1    male      Medium           0  3069.58
#
#                    age_knn  estimated_expenses_knn  offer_value_knn
# name
# DA3BAEB8BF604EB  32.772049                  7638.0       143.108044
# AEF3DE08DFED4E0  31.000000                  5784.0        63.637416
# B621BB29484E46D  25.000000                  4605.0       210.204552
# 2D0945802F92423  18.000000                  4459.0       131.110924
# 640ABFC7E49B403  56.000000                  4396.0       180.019199

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, DA3BAEB8BF604EB to 2E27EC78F50943B
# Data columns (total 23 columns):
# cc_len                           258 non-null object
# cc_startswith                    258 non-null object
# log_salary                       258 non-null float64
# log_age_knn                      258 non-null float64
# log_estimated_expenses_knn       258 non-null float64
# log_offer_value_knn              258 non-null float64
# scaled_salary                    258 non-null float64
# scaled_age_knn                   258 non-null float64
# scaled_estimated_expenses_knn    258 non-null float64
# scaled_offer_value_knn           258 non-null float64
# nan_age                          258 non-null bool
# not_nan_age                      258 non-null bool
# age                              189 non-null float64
# center                           258 non-null object
# customer_type                    258 non-null object
# emails                           258 non-null object
# gender                           258 non-null object
# offer_class                      258 non-null object
# phone_calls                      258 non-null object
# salary                           258 non-null float64
# age_knn                          258 non-null float64
# estimated_expenses_knn           258 non-null float64
# offer_value_knn                  258 non-null float64
# dtypes: bool(2), float64(13), object(8)
# memory usage: 44.8+ KB

# %%
a.shape
# Out:
# (1031, 24)

# %%
b.shape
# Out:
# (258, 23)

# %%
a.shape
# Out:
# (1031, 24)

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, DA3BAEB8BF604EB to 2E27EC78F50943B
# Data columns (total 23 columns):
# cc_len                           258 non-null object
# cc_startswith                    258 non-null object
# log_salary                       258 non-null float64
# log_age_knn                      258 non-null float64
# log_estimated_expenses_knn       258 non-null float64
# log_offer_value_knn              258 non-null float64
# scaled_salary                    258 non-null float64
# scaled_age_knn                   258 non-null float64
# scaled_estimated_expenses_knn    258 non-null float64
# scaled_offer_value_knn           258 non-null float64
# nan_age                          258 non-null bool
# not_nan_age                      258 non-null bool
# age                              189 non-null float64
# center                           258 non-null object
# customer_type                    258 non-null object
# emails                           258 non-null object
# gender                           258 non-null object
# offer_class                      258 non-null object
# phone_calls                      258 non-null object
# salary                           258 non-null float64
# age_knn                          258 non-null float64
# estimated_expenses_knn           258 non-null float64
# offer_value_knn                  258 non-null float64
# dtypes: bool(2), float64(13), object(8)
# memory usage: 44.8+ KB

# %%
test_df.shape
# Out:
# (258, 13)

# %%
train_df[0:4]
# Out:
#                 accepted offer_class  gender   age  phone_calls  emails  \
# name
# 8550AB469CB2445       no     Premium  female   NaN          1.0     2.0
# 07355EE27DD1493       no        High    male  32.0          0.0     0.0
# 034E73A251554F0      yes     Premium  female   NaN          1.0     1.0
# 0AF961B4AC7A439       no     Premium    male   NaN          0.0     1.0
#
#                 customer_code   salary offer_code customer_type number  \
# name
# 8550AB469CB2445          2678  1524.58        8CA             C  0F2A2
# 07355EE27DD1493        244360  1300.00        9DD             S  5F15A
# 034E73A251554F0        370365  1550.00        517             Q  AC578
# 0AF961B4AC7A439          2652   722.92        9CB             C  8A8CC
#
#                  offer_value  estimated_expenses center
# name
# 8550AB469CB2445   303.973257              7207.0      B
# 07355EE27DD1493    64.075055              3675.0      A
# 034E73A251554F0   108.581750              4750.0      B
# 0AF961B4AC7A439   155.495957              1401.0      A

# %%
train_df[3]

# %%
train_df[3:5]
# Out:
#                 accepted offer_class gender  age  phone_calls  emails  \
# name
# 0AF961B4AC7A439       no     Premium   male  NaN          0.0     1.0
# 8535BBCA690A4AE      yes     Premium   male  NaN          0.0     1.0
#
#                 customer_code   salary offer_code customer_type number  \
# name
#
# 80BBA1534FBF45F      708B2   207.036514              7333.0      A
# 94616715C7F3413      47B2A    59.376532              2696.0      A
# C9F863861E0F43A      016CC    55.757625              3617.0      B
# 4E0E4171A216434      C07F5   161.459710              6364.0      B
# FA7B6C5A96444D3      96221    65.311719              3168.0      B
# 6A2A46107B9D4C7      2F2B8   286.744146              1976.0      A
# 03533BC877F4455      FE3E9    81.313774              3751.0      B
# D45923436B58454      7142F   243.564406              1388.0      A
# F4E2209736C449B      DB4CB    75.285552              2388.0      B
# 247C7BE08D0C4ED   8.14E+09    85.301388              5176.0      B
# 745041C7461340B      63FD5   107.665053              3285.0      B
# CCF5A463D3BC472      D21EF   260.922393              2631.0      A
# F36F532F10C74E7      BFFC3   132.639570              1308.0      B
# DD6D10BD5B8F485      18F82   106.412846              6376.0      B
# 613317B41FA84FC      B586A    50.245356              4339.0      B
# B0ADC891D14946F      37BBF    71.310249              4788.0      A
# 5688A7DB4AFF46F      B838E    67.081598              5778.0      B
# 332075C1FBF544E      3423A    53.203102              4091.0      A
# 12CD64BAA6644D7      0B451    58.535096              6938.0      B
# FCDE060FC8E74C6      D207A   149.108793              4758.0      A
# C3BD23F4C51C4D6      4AE03   131.159825              6990.0      B
# 6591A721DD72439      5AB4A   100.046948              7459.0      B
# 9F1FD4386E7A419      2C4D9   162.182926              3865.0      B
# 63193E3CA0F840B      A3D8B    76.753846              2650.0      B
# 68DE08E524504CD      970CF   178.065119              6527.0      B
# B1AF7E969B0A48C      97751    99.312956              1772.0      B
# 7C6239D261BD4CA      E071D   118.123604              3917.0      A
# DAF778DD00F8407      55CC4    54.717256              6754.0      A
# F59BB97E471A4B6      3DBCF    84.868048              3005.0      B
# CFB8174011B2457      1D833   145.246513              5900.0      B
# DAB7F7F0F7D745A      ED468   143.458919              2330.0      B
# EEB84B2B59A4467      391C4   108.153445              5163.0      A
# 654586D69EA1468      A6DB0   129.737219              4216.0      A
# F0C22C56D03E402      7290B   210.810357              2763.0      A
# 62D287DD1E4841D      EA788   274.761119              6282.0      B
# 22CFBD0232FA449      6C9D0   150.689773              5027.0      A
# 7336C406DC1D4AD      98C5B    51.078096              1878.0      A
# 6AEFDFD6EEB74C8      ED5DA   107.400764              2171.0      A
# ED05F307FBE84DC      539D7   179.985763              7046.0      B
# 86D4FB50F10A47C      2605C   133.856215              7587.0      B
# BE1E8CA987174CF      0F27C    57.744836              7506.0      B
# 358EEC4160A4478      667C4    50.454597              7235.0      B

# %%
a[a['offer_code'].str.contains('E\+')].sort_values(['offer_code'])
# Out:
#                 cc_len cc_startswith  log_salary  log_age_knn  \
# name
# 1004379959394F2   ELSE          ELSE    7.276155     2.890372
# C9DE5A2E7BC24AB   ELSE          ELSE   -9.210340     3.688879
# 1A6D8FB4CCE04B6     58             P    9.025916     3.663562
# 2570BCC8C4C3421   ELSE             C    6.626718     3.514452
# 309837BADC1C477   ELSE          ELSE    7.681523     3.448590
# 4CF2BD7C25314F0   ELSE          ELSE    6.586172     3.650658
# F35EECD5042D405   ELSE             A    6.690842     3.385057
# DBA57BFE0FBB471   ELSE          ELSE    6.652863     3.359638
# 467839227F4E49E   ELSE          ELSE    7.316548     3.261489
# B4AF8E48A3C04EF   ELSE          ELSE    7.863267     3.526361
# 44843EB1709D4BC   ELSE          ELSE    7.863267     3.663562
# C6C2FB9E5C3A467   ELSE          ELSE    8.142500     2.890372
# B9B98DA7E7874D4   ELSE          ELSE    7.118826     4.110874
# 0639171AF75B4FF   ELSE          ELSE    6.856462     3.500022
# 6CF1543D1DDF481   ELSE          ELSE    6.671501     3.496508
# 0E525EAE8932414   ELSE          ELSE    6.656084     3.044522
# 26F287E09D104EC   ELSE          ELSE    7.316269     3.713572
# 06DFAFEE5FD0412   ELSE             C    7.613325     3.329685
# 90363EC43B9746C   ELSE          ELSE    6.666219     3.871201
# 81B0FCC40A1A452   ELSE          ELSE    6.652863     3.523258
# 17DB1678C2DE4F2     58          ELSE    7.863267     3.218876
# 196F8903F2C745B   ELSE          ELSE    7.383989     3.630156
# 3FA638BEB4CD498   ELSE          ELSE   -9.210340     2.995200
# 74D83055E6C844C   ELSE          ELSE    6.690842     3.806662
# 731EFA91D9B8423     58          ELSE    9.025916     4.025352
# 074B66A3B9F2426   ELSE          ELSE    7.207860     3.806662
# 2.27E+14          ELSE          ELSE    6.671501     3.401197
# 9CC1D4A4072B4ED   ELSE          ELSE    6.671501     2.944439
# A007F44AFF104D8   ELSE             A    6.690842     3.579043
#
#                  log_estimated_expenses_knn  log_offer_value_knn  \
# name
# 1004379959394F2                    8.474494             4.864278
# C9DE5A2E7BC24AB                    8.626765             5.172074
# 1A6D8FB4CCE04B6                    8.968014             4.218891
# 2570BCC8C4C3421                    8.167068             4.979573
# 309837BADC1C477                    8.546169             4.910904
# 4CF2BD7C25314F0                    8.552946             4.587439
# F35EECD5042D405                    7.994632             4.577639
# DBA57BFE0FBB471                    8.902047             4.368015
# 467839227F4E49E                    8.556029             5.267893
# B4AF8E48A3C04EF                    8.908559             5.037529
# 44843EB1709D4BC                    8.319474             4.945259
# C6C2FB9E5C3A467                    8.597297             4.212413
# B9B98DA7E7874D4                    7.999679             4.374836
# 0639171AF75B4FF                    8.369621             4.984716
# 6CF1543D1DDF481                    8.584104             4.275391
# 0E525EAE8932414                    7.720905             4.964324
# 26F287E09D104EC                    8.246696             5.185763
# 06DFAFEE5FD0412                    7.977282             4.930275
# 90363EC43B9746C                    8.215547             4.780477
# 81B0FCC40A1A452                    8.542861             4.556339
# 17DB1678C2DE4F2                    7.415175             4.519391
# 196F8903F2C745B                    7.138867             4.594998
# 3FA638BEB4CD498                    8.059592             4.457075
# 74D83055E6C844C                    8.568646             5.090573
# 731EFA91D9B8423                    7.545390             5.201979
# 074B66A3B9F2426                    8.255569             5.047581
# 2.27E+14                           8.167636             5.417434
# 9CC1D4A4072B4ED                    7.617760             4.632524
# A007F44AFF104D8                    7.593374             5.229252
#
#                  scaled_salary  scaled_age_knn  scaled_estimated_expenses_knn  \
# name
# 1004379959394F2      -0.360952       -1.411383                       0.093880
# C9DE5A2E7BC24AB      -0.642538        0.631047                       0.507570
# 1A6D8FB4CCE04B6       0.977492        0.538209                       1.698767
# 2570BCC8C4C3421      -0.495454        0.036656                      -0.571805
# 309837BADC1C477      -0.220199       -0.162159                       0.280775
# 4CF2BD7C25314F0      -0.501298        0.491790                       0.299150
# F35EECD5042D405      -0.485713       -0.341923                      -0.864748
# DBA57BFE0FBB471      -0.491558       -0.410707                       1.435748
# 467839227F4E49E      -0.349345       -0.660478                       0.307550
# B4AF8E48A3C04EF      -0.136025        0.074020                       1.460948
# 44843EB1709D4BC      -0.136025        0.538209                      -0.267312
# C6C2FB9E5C3A467       0.027131       -1.411383                       0.422522
# B9B98DA7E7874D4      -0.401944        2.580638                      -0.856873
# 0639171AF75B4FF      -0.457466       -0.008033                      -0.156539
# 6CF1543D1DDF481      -0.488717       -0.018817                       0.385248
# 0E525EAE8932414      -0.491071       -1.132870                      -1.237489
# 26F287E09D104EC      -0.349426        0.723884                      -0.418508
# 06DFAFEE5FD0412      -0.248042       -0.489547                      -0.891522
# 90363EC43B9746C      -0.489528        1.373748                      -0.479932
# 81B0FCC40A1A452      -0.491558        0.064242                       0.271851
# 17DB1678C2DE4F2      -0.136025       -0.761519                      -1.549332
# 196F8903F2C745B      -0.328889        0.419257                      -1.759852
# 3FA638BEB4CD498      -0.642538       -1.226696                      -0.760275
# 74D83055E6C844C      -0.485713        1.095235                       0.342199
# 731EFA91D9B8423       0.977492        2.116450                      -1.428060
# 074B66A3B9F2426      -0.379541        1.095235                      -0.400659
# 2.27E+14             -0.488717       -0.297330                      -0.570755
# 9CC1D4A4072B4ED      -0.488717       -1.318545                      -1.353511
# A007F44AFF104D8      -0.485713        0.244771                      -1.379236
#
#                  scaled_offer_value_knn  nan_age  not_nan_age  target  \
# name
# 1004379959394F2                0.022231    False         True   False
# C9DE5A2E7BC24AB                0.829192    False         True   False
# 1A6D8FB4CCE04B6               -1.042470    False         True    True
# 2570BCC8C4C3421                0.295837     True        False   False
# 309837BADC1C477                0.129094     True        False   False
# 4CF2BD7C25314F0               -0.519194    False         True   False
# F35EECD5042D405               -0.535750     True        False   False
# DBA57BFE0FBB471               -0.853635     True        False   False
# 467839227F4E49E                1.135489     True        False   False
# B4AF8E48A3C04EF                0.445758    False         True   False
# 44843EB1709D4BC                0.211084    False         True   False
# C6C2FB9E5C3A467               -1.050053    False         True   False
# B9B98DA7E7874D4               -0.844305    False         True   False
# 0639171AF75B4FF                0.308793     True        False   False
# 6CF1543D1DDF481               -0.974217    False         True   False
# 0E525EAE8932414                0.257816    False         True   False
# 26F287E09D104EC                0.871177    False         True   False
# 06DFAFEE5FD0412                0.174979     True        False   False
# 90363EC43B9746C               -0.157747    False         True   False
# 81B0FCC40A1A452               -0.571175     True        False    True
# 17DB1678C2DE4F2               -0.630864    False         True   False
# 196F8903F2C745B               -0.506314     True        False   False
# 3FA638BEB4CD498               -0.726671     True        False   False
# 74D83055E6C844C                0.590797    False         True    True
# 731EFA91D9B8423                0.921656    False         True    True
# 074B66A3B9F2426                0.472656    False         True    True
# 2.27E+14                       1.676201    False         True   False
# 0639171AF75B4FF   950.0000   4.00E+00             S  33D74      A  33.116164
# 6CF1543D1DDF481   789.5800   4.00E+03             S  458A7      B  33.000000
# 0E525EAE8932414   777.5000   5.00E+04             S  ADEE7      B  21.000000
# 26F287E09D104EC  1504.5800   5.00E+06             C  28B0B      B  41.000000
# 06DFAFEE5FD0412  2025.0000   5.00E+08             S  CD439      A  27.929546
# 90363EC43B9746C   785.4200   5.00E+08             S  FEEB7      A  48.000000
# 81B0FCC40A1A452   775.0000   5.00E+08             Q  CA06D      B  33.894669
# 17DB1678C2DE4F2  2600.0000   6.00E+00             C  8C07F      A  25.000000
# 196F8903F2C745B  1610.0000   6.00E+07             S  9E5EF      A  37.718713
# 3FA638BEB4CD498     0.0001   6.00E+09             S  26A16      B  19.989355
# 74D83055E6C844C   805.0000   7.00E+06             S  13794      B  45.000000
# 731EFA91D9B8423  8315.8300   8.00E+02             C  74C36      B  56.000000
# 074B66A3B9F2426  1350.0000   8.00E+06             S  DF9E0      B  45.000000
# 2.27E+14          789.5800   9.00E+01             S  81417      B  30.000000
# 9CC1D4A4072B4ED   789.5800   9.00E+04             S  79BB9      A  19.000000
# A007F44AFF104D8   805.0000   9.00E+05             S  9CFD2      B  35.839239
#
#                  estimated_expenses_knn  offer_value_knn
# name
# 1004379959394F2                  4791.0       129.577331
# C9DE5A2E7BC24AB                  5579.0       176.279975
# 1A6D8FB4CCE04B6                  7848.0        67.958094
# 2570BCC8C4C3421                  3523.0       145.412245
# 309837BADC1C477                  5147.0       135.762026
# 4CF2BD7C25314F0                  5182.0        98.242553
# F35EECD5042D405                  2965.0        97.284387
# DBA57BFE0FBB471                  7347.0        78.886864
# 467839227F4E49E                  5198.0       194.006804
# B4AF8E48A3C04EF                  7395.0       154.088854
# 44843EB1709D4BC                  4103.0       140.507167
# C6C2FB9E5C3A467                  5417.0        67.519272
# B9B98DA7E7874D4                  2980.0        79.426839
# 0639171AF75B4FF                  4314.0       146.162048
# 6CF1543D1DDF481                  5346.0        71.908229
# 0E525EAE8932414                  2255.0       143.211741
# 26F287E09D104EC                  3815.0       178.709829
# 06DFAFEE5FD0412                  2914.0       138.417582
# 90363EC43B9746C                  3698.0       119.161206
# 81B0FCC40A1A452                  5130.0        95.234189
# 17DB1678C2DE4F2                  1661.0        91.779684
# 196F8903F2C745B                  1260.0        98.987986
# 3FA638BEB4CD498                  3164.0        86.234876
# 74D83055E6C844C                  5264.0       162.482961
# 731EFA91D9B8423                  1892.0       181.631280
# 074B66A3B9F2426                  3849.0       155.645549
# 2.27E+14                         3525.0       225.300348
# 9CC1D4A4072B4ED                  2034.0       102.773104
# A007F44AFF104D8                  1985.0       186.653163

# %%
a.groupby(['cc_len', 'target']).size()
# Out:
# cc_len  target
# 58      False      96
#         True      139
# ELSE    False     544
#         True      252
# dtype: int64

# %%
a.groupby(['cc_startswith', 'target']).size()
# Out:
# cc_startswith  target
# A              False      24
#                True        2
# C              False      40
#                True       19
# ELSE           False     553
#                True      320
# P              False      23
#                True       50
# dtype: int64

# %%
a[a['cc_len'] > 8]['target'].value_counts()
# Out:
# False    95
# True     51
# Name: target, dtype: int64

# %%
a[a['cc_len'] == 8]['target'].value_counts()
# Out:
# True     49
# False    39
# Name: target, dtype: int64

# %%
a[a['cc_len'].isin([5,8])]['target'].value_counts()
# Out:
# True     139
# False     96
# Name: target, dtype: int64

# %%
a[~a['cc_len'].isin([5,8])]['target'].value_counts()
# Out:
# False    544
# True     252
# Name: target, dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1031 entries, 8550AB469CB2445 to 358EEC4160A4478
# Data columns (total 26 columns):
# cc_len                           1031 non-null int64
# log_salary                       1031 non-null float64
# log_age_knn                      1031 non-null float64
# log_estimated_expenses_knn       1031 non-null float64
# log_offer_value_knn              1031 non-null float64
# scaled_salary                    1031 non-null float64
# scaled_age_knn                   1031 non-null float64
# scaled_estimated_expenses_knn    1031 non-null float64
# scaled_offer_value_knn           1031 non-null float64
# nan_age                          1031 non-null bool
# not_nan_age                      1031 non-null bool
# target                           1031 non-null bool
# offer_class                      1031 non-null object
# gender                           1031 non-null object
# age                              688 non-null float64
# phone_calls                      1031 non-null object
# emails                           1031 non-null object
# customer_code                    1031 non-null object
# salary                           1031 non-null float64
# offer_code                       1031 non-null object
# customer_type                    1031 non-null object
# number                           1031 non-null object
# center                           1031 non-null object
# age_knn                          1031 non-null float64
# estimated_expenses_knn           1031 non-null float64
# offer_value_knn                  1031 non-null float64
# dtypes: bool(3), float64(13), int64(1), object(9)
# memory usage: 196.3+ KB

# %%
a[a['cc_len']>9]['target']
# Out:
#                  target  target
# name
# 174003D902C3450   False   False
# 7D1020DC3B34422   False   False
# F0FEC2493E11410   False   False
# 24D13EF5820C49E    True    True
# 282C859D670D45B   False   False
# 04779E8B7D83463   False   False
# 9D8E425268E8421    True    True
# E4B445C848E4401   False   False
# A5008A88F1BE45E   False   False
# 9DDF7D7DC39242A   False   False
# C717849A05FC485   False   False
# A366C2F78BB644D    True    True
# A6E7AABF28E34E2   False   False
# 71679134791D413    True    True
# C6C2FB9E5C3A467   False   False
# 898F806196AD42D   False   False
# 257396C7ACFE472   False   False
# 1CE4707516E24A8   False   False
# BDC0A564861642B    True    True
# 939BA02CE9B144D   False   False
# E1AF26C5FC62405   False   False
# A0525DC64D8447E    True    True
# DD843EBD0A5745C    True    True
# 8AF05906BDCB45D   False   False
# A3CD1F67D9DF49C    True    True
# 997C1CC7BDD24F7   False   False
# 467839227F4E49E   False   False
# F27A2989E4714C0   False   False
# 9239B165CF6846F   False   False
# 76AD01A2BD7942E   False   False
# AD9C60321A5D4EB   False   False
# 57F238CB903249C   False   False
# 2570BCC8C4C3421   False   False
# 6EF2BB5847A4409    True    True
# E4E07D36A58349E    True    True
# 71EBCC9F41C2439   False   False
# 114B8B7CCAEA445   False   False
# BC7F5AD90EDD494    True    True
# D8658A2A382A4F9   False   False
# 756B268A719342E   False   False
# 4B98367817FC47E   False   False
# 3A6E70C61F8B42D    True    True
# 920616D5B7064C2   False   False
# 6AFA5D80F2CB408    True    True
# FD44BF0A6757404   False   False
# 3A8ABEBBDC014D1   False   False
# 1F45BC1B360D4CC   False   False
# DDA94E4229D049E    True    True
# D30FC02A184B4AE    True    True
# 78D2D084287A461   False   False
# E4B9DD8418B540C    True    True
# A48E3314039642E   False   False
# 61A51D95C4FF4E7    True    True
# 445AF931313940F    True    True
# 3ED9B47AD1B1420    True    True
# 06B2610415EE492   False   False
# 76EDA34C33814EE   False   False
# 52A0CCD64A1B4B0    True    True
# 82F115804DEE4EB    True    True
# 1.49E+14           True    True
# 7E9A16FE481A4E7   False   False
# 471F6097FB3945A   False   False
# B5196F36CBBA4DD    True    True
# D5CAA34A8AA643D    True    True
# 4C4920EDE90E42B   False   False
# 2FF130784F8C43E   False   False
# 1EA2CD7748C04FD   False   False
# 25B5FF5ADCE0483   False   False
# 7B19BB55F87C47A    True    True
# EB00397D8E90421    True    True
# 6202DEF5469B4AF   False   False
# 97BECBAC58434D7    True    True
# BA3BDAF438664FA   False   False
# 486C2FC81E5D458    True    True
# 0786A55B8F1B4EB    True    True
# E5E80BD346BF426    True    True
# 623D8903C94B423    True    True
# B7243CF0A57D4B5    True    True
# B401FA2C0D064FB   False   False
# 83647058968548B   False   False
# 41BEF6C42F4D4DC    True    True
# CB6EAA13AA334F4    True    True
# 3B59D9FC9ADD46A   False   False
# 68F639C67A904C7    True    True
# 40F5307EC5D542A   False   False
# D35A2D33F9F5411   False   False
# ABA5AE22FD8A414   False   False
# B0D8C4F85B9547E   False   False
# A91CD04275134AD    True    True
# F373585F7C43407   False   False
# 17EB308B4E2B4B1   False   False
# 7D9FB4887A9A475   False   False
# C0DB8EE3BB4D460   False   False
# E495AAE0874845D   False   False
# 726A294AD65B41A   False   False
# D9B658D77F56432    True    True
# 0A3A42BB9A86470    True    True
# 7885E6B76D614FC    True    True
# D3DF686584354B9    True    True
# F1C1DB831D6C4A6   False   False
# ACCA898FED0B4C1   False   False
# 87C7D2F519CD472    True    True
# 03181D982C024E5    True    True
# 68829B29FAA148E    True    True
# 72CF2FA29F38475   False   False
# 9FE35808EACD4B0   False   False
# 4EED2E88AA514EF   False   False
# EA9AAF8305B642F   False   False
# 7A1E6081AEFB4D6   False   False
# 2EC720F51F2E4EB   False   False
# EA3EAD5AE4C54EC   False   False
# 86B6443CBEC64DE   False   False
# 581E57F5AAEF450   False   False
# BA27DE61C13547D   False   False
# 46C3B4A7E2E3443   False   False
# 574F11CC23AB46A   False   False
# 332075C1FBF544E   False   False
# FCDE060FC8E74C6   False   False
# ED05F307FBE84DC    True    True

# %%
train_df.shape
# Out:
# (1031, 14)

# %% [markdown]
# #### encode target

# %%
train_df['target'] = train_df['accepted'] == 'yes'

# %%
#train_df['target']

# %% [markdown]
# #### feature engineering

# %%
enc = LeaveOneOutEncoder(train_df=train_df, test_df=test_df, columns_to_encode=[], target_column=, random_state=42, mean=1, std=0.05)
# Out:
#   File "<ipython-input-59-c8a4f36707a6>", line 1
#     enc = LeaveOneOutEncoder(train_df=train_df, test_df=test_df, columns_to_encode=[], target_column=, random_state=42, mean=1, std=0.05)
#                                                                                                      ^
# SyntaxError: invalid syntax
